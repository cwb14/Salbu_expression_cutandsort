# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Read local table into jupyter notebook

# %%
Sal_G = pd.read_table("/Users/cbenson/Salbu/DE/DESeq2_genes/Kallisto.gene.count.matrix.wAnnot.matrix")
Sal_G
# Out:
#                                                      sampleA sampleB  \
# TRINITY_DN1486_c0_g2^RS27A_LUPAL^RL40_CRYNJ^RL4...  Infected     Non
# TRINITY_DN1686_c0_g1^ZIP7_ARATH^Zip                 Infected     Non
# TRINITY_DN1677_c2_g4                                Infected     Non
# TRINITY_DN1606_c5_g11                               Infected     Non
# TRINITY_DN737_c0_g1^SSU1_ARTOC^SSU1_TRIRU^SLAC1     Infected     Non
# TRINITY_DN1582_c1_g1                                Infected     Non
# TRINITY_DN1429_c1_g2                                Infected     Non
# TRINITY_DN303_c0_g1                                 Infected     Non
# TRINITY_DN1678_c2_g1^YFF7_SCHPO^DUF2015             Infected     Non
# TRINITY_DN1537_c0_g1                                Infected     Non
# TRINITY_DN1226_c0_g1                                Infected     Non
# TRINITY_DN1726_c3_g1                                Infected     Non
# TRINITY_DN1654_c0_g1                                Infected     Non
# ...

# %%
Sal_G.sort_values(by='padj')
# Out:
#                                                      sampleA sampleB  \
# TRINITY_DN1486_c0_g2^RS27A_LUPAL^RL40_CRYNJ^RL4...  Infected     Non
# TRINITY_DN1686_c0_g1^ZIP7_ARATH^Zip                 Infected     Non
# TRINITY_DN1677_c2_g4                                Infected     Non
# TRINITY_DN1606_c5_g11                               Infected     Non
# TRINITY_DN737_c0_g1^SSU1_ARTOC^SSU1_TRIRU^SLAC1     Infected     Non
# TRINITY_DN1582_c1_g1                                Infected     Non
# TRINITY_DN1429_c1_g2                                Infected     Non
# TRINITY_DN303_c0_g1                                 Infected     Non
# TRINITY_DN1678_c2_g1^YFF7_SCHPO^DUF2015             Infected     Non
# TRINITY_DN1537_c0_g1                                Infected     Non
# TRINITY_DN1226_c0_g1                                Infected     Non
# TRINITY_DN1726_c3_g1                                Infected     Non
# TRINITY_DN1654_c0_g1                                Infected     Non
# ...

# %%
# Out:
#                                                      sampleA sampleB  \
# TRINITY_DN1486_c0_g2^RS27A_LUPAL^RL40_CRYNJ^RL4...  Infected     Non
# TRINITY_DN1686_c0_g1^ZIP7_ARATH^Zip                 Infected     Non
# TRINITY_DN1677_c2_g4                                Infected     Non
# TRINITY_DN1606_c5_g11                               Infected     Non
# TRINITY_DN737_c0_g1^SSU1_ARTOC^SSU1_TRIRU^SLAC1     Infected     Non
# TRINITY_DN1582_c1_g1                                Infected     Non
# TRINITY_DN1429_c1_g2                                Infected     Non
# TRINITY_DN303_c0_g1                                 Infected     Non
# TRINITY_DN1678_c2_g1^YFF7_SCHPO^DUF2015             Infected     Non
# TRINITY_DN1537_c0_g1                                Infected     Non
# TRINITY_DN1226_c0_g1                                Infected     Non
# TRINITY_DN1726_c3_g1                                Infected     Non
# TRINITY_DN1654_c0_g1                                Infected     Non
# ...

# %%
SG_pcut = Sal_G[Sal_G.padj < 0.05]
SG_pcut.tail(5)
# Out:
#                                                   sampleA sampleB  baseMeanA  \
# TRINITY_DN1584_c0_g6^DPOA_SCHPO^DNA_pol_alpha_N  Infected     Non   0.000000
# TRINITY_DN189_c0_g1                              Infected     Non  14.169012
# TRINITY_DN1227_c0_g1^PHOA_ASPFU^Phosphoesterase  Infected     Non   6.121589
# TRINITY_DN1556_c0_g3                             Infected     Non   0.000000
# TRINITY_DN2645_c0_g1^STRAP_RAT^WD40              Infected     Non   2.971373
#
#                                                  baseMeanB  baseMean  \
# TRINITY_DN1584_c0_g6^DPOA_SCHPO^DNA_pol_alpha_N   7.670483  3.835241
# TRINITY_DN189_c0_g1                               0.668070  7.418541
# TRINITY_DN1227_c0_g1^PHOA_ASPFU^Phosphoesterase  13.072005  9.596797
# TRINITY_DN1556_c0_g3                              8.778739  4.389369
# TRINITY_DN2645_c0_g1^STRAP_RAT^WD40              13.632849  8.302111
#
#                                                  log2FoldChange     lfcSE  \
# ...

# %%
SG1 = SG_pcut.sort_values (by= 'log2FoldChange', ascending=False)

# %%
SG_up = SG1[SG1.log2FoldChange > 0]
SG_up
# Out:
#                                                      sampleA sampleB  \
# TRINITY_DN1726_c3_g1                                Infected     Non
# TRINITY_DN1726_c3_g9                                Infected     Non
# TRINITY_DN1726_c2_g1^ART2_YEAST                     Infected     Non
# TRINITY_DN1677_c2_g4                                Infected     Non
# TRINITY_DN1226_c0_g1                                Infected     Non
# TRINITY_DN772_c0_g1^TAR1_KLULA                      Infected     Non
# TRINITY_DN131_c0_g1                                 Infected     Non
# TRINITY_DN1035_c0_g1                                Infected     Non
# TRINITY_DN684_c0_g1                                 Infected     Non
# TRINITY_DN1429_c1_g2                                Infected     Non
# TRINITY_DN2657_c0_g1                                Infected     Non
# TRINITY_DN2199_c0_g1                                Infected     Non
# TRINITY_DN2112_c0_g1                                Infected     Non
# ...

# %%
SG2 = SG_pcut.sort_values (by= 'log2FoldChange', ascending=True)

# %%
SG_down = SG2[SG2.log2FoldChange < 0]
SG_down
# Out:
#                                                      sampleA sampleB  \
# TRINITY_DN1520_c5_g8^ASL1_SCHPO^Glyco_hydro_cc      Infected     Non
# TRINITY_DN1560_c0_g1^ASL1_SCHPO^Glyco_hydro_cc      Infected     Non
# TRINITY_DN1505_c6_g4                                Infected     Non
# TRINITY_DN1540_c1_g1                                Infected     Non
# TRINITY_DN1629_c3_g6^ALL7_ARTBC^DPBB_1              Infected     Non
# TRINITY_DN1616_c1_g1                                Infected     Non
# TRINITY_DN1483_c1_g11                               Infected     Non
# TRINITY_DN1638_c3_g3^DIP5_YEAST^AFLT_ASPPU^AURT...  Infected     Non
# TRINITY_DN1515_c2_g3^HEM6_DROME^YVC1_CANAL^SNG1...  Infected     Non
# TRINITY_DN1505_c6_g6^ASPR1_PHARH^Asp                Infected     Non
# TRINITY_DN1648_c3_g1^PTPRG_CHICK^LAR_CAEEL^GRI2...  Infected     Non
# TRINITY_DN1616_c2_g1                                Infected     Non
# TRINITY_DN1552_c2_g1^POX18_CANMA^DHB4_MOUSE^SCP2    Infected     Non
# ...

# %%
SG_down.to_csv('Salbu_genes_down.txt', sep='\t')

# %%
SG_up.to_csv('Salbu_genes_up.txt', sep='\t')
